# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup
import datetime
import matplotlib.pyplot as plt
import urllib
from pykrx import stock

# %%
# today's 시가총액 Top 300 code lists

df = stock.get_market_cap_by_ticker(datetime.date.today().strftime('%Y%m%d'))
df_t50 = df.sort_values('시가총액', ascending=False).head(300) # 50
code_lists = df_t50.index.tolist()

# code_lists

# %%
# today's 시가총액 Top 50 code lists covert to stock name lists

stock_name_lists = []
for ticker in code_lists:
    stock_name_lists.append(stock.get_market_ticker_name(ticker))
    
# stock_lists

# %%
# Build name code index

code_names = dict(zip(code_lists, stock_name_lists))
# code_names

# %%
# 주가데이터 with next day price up and down indicator

fail_count = 0
ok_count = 0

start = "20180701" 
end = "20210716" 

for code in code_lists:
  try:
    result = stock.get_market_ohlcv_by_date(start, end, code)
    print ("Read data for " + code + " " + repr(result.shape))
    ok_count += 1
  except:
    print ("Could not read data for " + code)
    fail_count += 1

  print(str(ok_count) + " loads, " + str(fail_count) + " failures")                               # 결측치 제거

  # 새로운 칼럼 생성
  # (Price : 당일 대비 다음날 주가가 상승했으면 1, 하락했으면 0 표시)
  result['UpDown'] = 0
  for i in range(0, result.shape[0]-1):
      if result['종가'][i] < result['종가'][i+1]:
          result['UpDown'][i] = 1
      else:
          result['UpDown'][i] = 0

  # 파일 저장
  result.to_csv(code+'_주가데이터.csv')
# Out:
# Read data for 005930 (752, 5)
# 1 loads, 0 failures
# <ipython-input-74-daf325ea2538>:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   result['UpDown'][i] = 1
# <ipython-input-74-daf325ea2538>:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   result['UpDown'][i] = 0
# Read data for 000660 (752, 5)
# 2 loads, 0 failures
# Read data for 035420 (752, 5)
# 3 loads, 0 failures
# Read data for 035720 (752, 5)
# 4 loads, 0 failures
# Read data for 207940 (752, 5)
# 5 loads, 0 failures
# Read data for 005935 (752, 5)
# 6 loads, 0 failures
# Read data for 051910 (752, 5)
# 7 loads, 0 failures
# Read data for 006400 (752, 5)
# 8 loads, 0 failures
# Read data for 005380 (752, 5)
# 9 loads, 0 failures
# Read data for 068270 (752, 5)
# 10 loads, 0 failures
# Read data for 000270 (752, 5)
# 11 loads, 0 failures
# Read data for 005490 (752, 5)
# 12 loads, 0 failures
# Read data for 066570 (752, 5)
# 13 loads, 0 failures
# Read data for 051900 (752, 5)
# 14 loads, 0 failures
# Read data for 012330 (752, 5)
# 15 loads, 0 failures
# Read data for 028260 (752, 5)
# 16 loads, 0 failures
# Read data for 096770 (752, 5)
# 17 loads, 0 failures
# Read data for 017670 (752, 5)
# 18 loads, 0 failures
# Read data for 105560 (752, 5)
# 19 loads, 0 failures
# Read data for 055550 (752, 5)
# 20 loads, 0 failures
# Read data for 034730 (752, 5)
# 21 loads, 0 failures
# Read data for 091990 (752, 5)
# 22 loads, 0 failures
# Read data for 036570 (752, 5)
# 23 loads, 0 failures
# Read data for 011200 (752, 5)
# 24 loads, 0 failures
# Read data for 015760 (752, 5)
# 25 loads, 0 failures
# Read data for 003550 (752, 5)
# 26 loads, 0 failures
# Read data for 361610 (48, 5)
# 27 loads, 0 failures
# Read data for 032830 (752, 5)
# 28 loads, 0 failures
# Read data for 018260 (752, 5)
# 29 loads, 0 failures
# Read data for 090430 (752, 5)
# 30 loads, 0 failures
# Read data for 009150 (752, 5)
# 31 loads, 0 failures
# Read data for 086790 (752, 5)
# 32 loads, 0 failures
# Read data for 302440 (85, 5)
# 33 loads, 0 failures
# Read data for 251270 (752, 5)
# 34 loads, 0 failures
# Read data for 003670 (752, 5)
# 35 loads, 0 failures
# Read data for 352820 (189, 5)
# 36 loads, 0 failures
# Read data for 033780 (752, 5)
# 37 loads, 0 failures
# Read data for 010950 (752, 5)
# 38 loads, 0 failures
# Read data for 034020 (752, 5)
# 39 loads, 0 failures
# Read data for 003490 (752, 5)
# 40 loads, 0 failures
# Read data for 000810 (752, 5)
# 41 loads, 0 failures
# Read data for 326030 (259, 5)
# 42 loads, 0 failures
# Read data for 011170 (752, 5)
# 43 loads, 0 failures
# Read data for 010130 (752, 5)
# 44 loads, 0 failures
# Read data for 030200 (752, 5)
# 45 loads, 0 failures
# Read data for 009540 (752, 5)
# 46 loads, 0 failures
# Read data for 018880 (752, 5)
# 47 loads, 0 failures
# Read data for 034220 (752, 5)
# 48 loads, 0 failures
# Read data for 316140 (602, 5)
# 49 loads, 0 failures
# Read data for 009830 (752, 5)
# 50 loads, 0 failures
# Read data for 024110 (752, 5)
# 51 loads, 0 failures
# Read data for 086280 (752, 5)
# 52 loads, 0 failures
# Read data for 097950 (752, 5)
# 53 loads, 0 failures
# Read data for 004020 (752, 5)
# 54 loads, 0 failures
# Read data for 011780 (752, 5)
# 55 loads, 0 failures
# Read data for 000720 (752, 5)
# 56 loads, 0 failures
# Read data for 032640 (752, 5)
# 57 loads, 0 failures
# Read data for 293490 (210, 5)
# 58 loads, 0 failures
# Read data for 011790 (752, 5)
# 59 loads, 0 failures
# Read data for 161390 (752, 5)
# 60 loads, 0 failures
# Read data for 137310 (1, 5)
# 61 loads, 0 failures
# Read data for 021240 (752, 5)
# 62 loads, 0 failures
# Read data for 247540 (589, 5)
# 63 loads, 0 failures
# Read data for 006800 (752, 5)
# 64 loads, 0 failures
# Read data for 071050 (752, 5)
# 65 loads, 0 failures
# Read data for 263750 (752, 5)
# 66 loads, 0 failures
# Read data for 068760 (752, 5)
# 67 loads, 0 failures
# Read data for 011070 (752, 5)
# 68 loads, 0 failures
# Read data for 035250 (752, 5)
# 69 loads, 0 failures
# Read data for 267250 (752, 5)
# 70 loads, 0 failures
# Read data for 008930 (752, 5)
# 71 loads, 0 failures
# Read data for 002790 (752, 5)
# 72 loads, 0 failures
# Read data for 271560 (752, 5)
# 73 loads, 0 failures
# Read data for 088980 (752, 5)
# 74 loads, 0 failures
# Read data for 241560 (752, 5)
# 75 loads, 0 failures
# Read data for 139480 (752, 5)
# 76 loads, 0 failures
# Read data for 383220 (41, 5)
# 77 loads, 0 failures
# Read data for 028050 (752, 5)
# 78 loads, 0 failures
# Read data for 000100 (752, 5)
# 79 loads, 0 failures
# Read data for 180640 (752, 5)
# 80 loads, 0 failures
# Read data for 036490 (752, 5)
# 81 loads, 0 failures
# Read data for 096530 (752, 5)
# 82 loads, 0 failures
# Read data for 000120 (752, 5)
# 83 loads, 0 failures
# Read data for 005387 (752, 5)
# 84 loads, 0 failures
# Read data for 029780 (752, 5)
# 85 loads, 0 failures
# Read data for 004990 (752, 5)
# 86 loads, 0 failures
# Read data for 003410 (752, 5)
# 87 loads, 0 failures
# Read data for 078930 (752, 5)
# 88 loads, 0 failures
# Read data for 010140 (752, 5)
# 89 loads, 0 failures
# Read data for 128940 (752, 5)
# 90 loads, 0 failures
# Read data for 028670 (752, 5)
# 91 loads, 0 failures
# Read data for 016360 (752, 5)
# 92 loads, 0 failures
# Read data for 005830 (752, 5)
# 93 loads, 0 failures
# Read data for 035760 (752, 5)
# 94 loads, 0 failures
# Read data for 020150 (752, 5)
# 95 loads, 0 failures
# Read data for 006360 (752, 5)
# 96 loads, 0 failures
# Read data for 298020 (743, 5)
# 97 loads, 0 failures
# Read data for 007070 (752, 5)
# 98 loads, 0 failures
# Read data for 006280 (752, 5)
# 99 loads, 0 failures
# Read data for 112610 (752, 5)
# 100 loads, 0 failures
# Read data for 008770 (752, 5)
# 101 loads, 0 failures
# Read data for 028300 (752, 5)
# 102 loads, 0 failures
# Read data for 196170 (752, 5)
# 103 loads, 0 failures
# Read data for 005940 (752, 5)
# 104 loads, 0 failures
# Read data for 042660 (752, 5)
# 105 loads, 0 failures
# Read data for 019170 (752, 5)
# 106 loads, 0 failures
# Read data for 307950 (572, 5)
# 107 loads, 0 failures
# Read data for 042670 (752, 5)
# 108 loads, 0 failures
# Read data for 336260 (434, 5)
# 109 loads, 0 failures
# Read data for 036460 (752, 5)
# 110 loads, 0 failures
# Read data for 047810 (752, 5)
# 111 loads, 0 failures
# Read data for 008560 (752, 5)
# 112 loads, 0 failures
# Read data for 272210 (416, 5)
# 113 loads, 0 failures
# Read data for 066970 (752, 5)
# 114 loads, 0 failures
# Read data for 145020 (752, 5)
# 115 loads, 0 failures
# Read data for 023530 (752, 5)
# 116 loads, 0 failures
# Read data for 081660 (752, 5)
# 117 loads, 0 failures
# Read data for 039490 (752, 5)
# 118 loads, 0 failures
# Read data for 012750 (752, 5)
# 119 loads, 0 failures
# Read data for 010620 (752, 5)
# 120 loads, 0 failures
# Read data for 047040 (752, 5)
# 121 loads, 0 failures
# Read data for 088350 (752, 5)
# 122 loads, 0 failures
# Read data for 285130 (752, 5)
# 123 loads, 0 failures
# Read data for 204320 (752, 5)
# 124 loads, 0 failures
# Read data for 001040 (752, 5)
# 125 loads, 0 failures
# Read data for 051915 (752, 5)
# 126 loads, 0 failures
# Read data for 026960 (752, 5)
# 127 loads, 0 failures
# Read data for 282330 (752, 5)
# 128 loads, 0 failures
# Read data for 000990 (752, 5)
# 129 loads, 0 failures
# Read data for 009240 (752, 5)
# 130 loads, 0 failures
# Read data for 375500 (120, 5)
# 131 loads, 0 failures
# Read data for 138040 (752, 5)
# 132 loads, 0 failures
# Read data for 014680 (752, 5)
# 133 loads, 0 failures
# Read data for 030000 (752, 5)
# 134 loads, 0 failures
# Read data for 047050 (752, 5)
# 135 loads, 0 failures
# Read data for 253450 (752, 5)
# 136 loads, 0 failures
# Read data for 058470 (752, 5)
# 137 loads, 0 failures
# Read data for 010060 (752, 5)
# 138 loads, 0 failures
# Read data for 005385 (752, 5)
# 139 loads, 0 failures
# Read data for 002380 (752, 5)
# 140 loads, 0 failures
# Read data for 357780 (234, 5)
# 141 loads, 0 failures
# Read data for 004170 (752, 5)
# 142 loads, 0 failures
# Read data for 012510 (752, 5)
# 143 loads, 0 failures
# Read data for 011210 (752, 5)
# 144 loads, 0 failures
# Read data for 000060 (752, 5)
# 145 loads, 0 failures
# Read data for 012450 (752, 5)
# 146 loads, 0 failures
# Read data for 011000 (752, 5)
# 147 loads, 0 failures
# Read data for 298050 (743, 5)
# 148 loads, 0 failures
# Read data for 004800 (752, 5)
# 149 loads, 0 failures
# Read data for 064350 (752, 5)
# 150 loads, 0 failures
# Read data for 000080 (752, 5)
# 151 loads, 0 failures
# Read data for 138930 (752, 5)
# 152 loads, 0 failures
# Read data for 052690 (752, 5)
# 153 loads, 0 failures
# Read data for 001440 (752, 5)
# 154 loads, 0 failures
# Read data for 240810 (752, 5)
# 155 loads, 0 failures
# Read data for 064760 (752, 5)
# 156 loads, 0 failures
# Read data for 000880 (752, 5)
# 157 loads, 0 failures
# Read data for 278280 (604, 5)
# 158 loads, 0 failures
# Read data for 001450 (752, 5)
# 159 loads, 0 failures
# Read data for 095700 (752, 5)
# 160 loads, 0 failures
# Read data for 006260 (752, 5)
# 161 loads, 0 failures
# Read data for 120110 (752, 5)
# 162 loads, 0 failures
# Read data for 003090 (752, 5)
# 163 loads, 0 failures
# Read data for 294870 (752, 5)
# 164 loads, 0 failures
# Read data for 032500 (752, 5)
# 165 loads, 0 failures
# Read data for 007310 (752, 5)
# 166 loads, 0 failures
# Read data for 017800 (752, 5)
# 167 loads, 0 failures
# Read data for 004370 (752, 5)
# 168 loads, 0 failures
# Read data for 237690 (752, 5)
# 169 loads, 0 failures
# Read data for 051600 (752, 5)
# 170 loads, 0 failures
# Read data for 007390 (752, 5)
# 171 loads, 0 failures
# Read data for 069960 (752, 5)
# 172 loads, 0 failures
# Read data for 108320 (752, 5)
# 173 loads, 0 failures
# Read data for 001230 (752, 5)
# 174 loads, 0 failures
# Read data for 073240 (752, 5)
# 175 loads, 0 failures
# Read data for 004000 (752, 5)
# 176 loads, 0 failures
# Read data for 042700 (752, 5)
# 177 loads, 0 failures
# Read data for 010120 (752, 5)
# 178 loads, 0 failures
# Read data for 006650 (752, 5)
# 179 loads, 0 failures
# Read data for 336370 (434, 5)
# 180 loads, 0 failures
# Read data for 111770 (752, 5)
# 181 loads, 0 failures
# Read data for 069620 (752, 5)
# 182 loads, 0 failures
# Read data for 000150 (752, 5)
# 183 loads, 0 failures
# Read data for 000240 (752, 5)
# 184 loads, 0 failures
# Read data for 950210 (111, 5)
# 185 loads, 0 failures
# Read data for 010780 (752, 5)
# 186 loads, 0 failures
# Read data for 178920 (752, 5)
# 187 loads, 0 failures
# Read data for 000210 (752, 5)
# 188 loads, 0 failures
# Read data for 098460 (752, 5)
# 189 loads, 0 failures
# Read data for 051905 (752, 5)
# 190 loads, 0 failures
# Read data for 048260 (752, 5)
# 191 loads, 0 failures
# Read data for 013890 (426, 5)
# 192 loads, 0 failures
# Read data for 016380 (752, 5)
# 193 loads, 0 failures
# Read data for 248070 (114, 5)
# 194 loads, 0 failures
# Read data for 009900 (152, 5)
# 195 loads, 0 failures
# Read data for 005250 (752, 5)
# 196 loads, 0 failures
# Read data for 181710 (752, 5)
# 197 loads, 0 failures
# Read data for 005290 (752, 5)
# 198 loads, 0 failures
# Read data for 268600 (664, 5)
# 199 loads, 0 failures
# Read data for 005850 (752, 5)
# 200 loads, 0 failures
# Read data for 025900 (752, 5)
# 201 loads, 0 failures
# Read data for 034230 (752, 5)
# 202 loads, 0 failures
# Read data for 185750 (752, 5)
# 203 loads, 0 failures
# Read data for 078340 (752, 5)
# 204 loads, 0 failures
# Read data for 001740 (752, 5)
# 205 loads, 0 failures
# Read data for 139130 (752, 5)
# 206 loads, 0 failures
# Read data for 192820 (752, 5)
# 207 loads, 0 failures
# Read data for 003000 (752, 5)
# 208 loads, 0 failures
# Read data for 086900 (752, 5)
# 209 loads, 0 failures
# Read data for 056190 (752, 5)
# 210 loads, 0 failures
# Read data for 067160 (752, 5)
# 211 loads, 0 failures
# Read data for 030190 (752, 5)
# 212 loads, 0 failures
# Read data for 330590 (426, 5)
# 213 loads, 0 failures
# Read data for 041510 (752, 5)
# 214 loads, 0 failures
# Read data for 200130 (752, 5)
# 215 loads, 0 failures
# Read data for 035900 (752, 5)
# 216 loads, 0 failures
# Read data for 175330 (752, 5)
# 217 loads, 0 failures
# Read data for 032350 (752, 5)
# 218 loads, 0 failures
# Read data for 085660 (752, 5)
# 219 loads, 0 failures
# Read data for 213420 (752, 5)
# 220 loads, 0 failures
# Read data for 031430 (752, 5)
# 221 loads, 0 failures
# Read data for 141080 (752, 5)
# 222 loads, 0 failures
# Read data for 039030 (752, 5)
# 223 loads, 0 failures
# Read data for 363280 (202, 5)
# 224 loads, 0 failures
# Read data for 214150 (752, 5)
# 225 loads, 0 failures
# Read data for 235980 (390, 5)
# 226 loads, 0 failures
# Read data for 060250 (752, 5)
# 227 loads, 0 failures
# Read data for 323990 (202, 5)
# 228 loads, 0 failures
# Read data for 066575 (752, 5)
# 229 loads, 0 failures
# Read data for 206650 (752, 5)
# 230 loads, 0 failures
# Read data for 005300 (752, 5)
# 231 loads, 0 failures
# Read data for 004490 (752, 5)
# 232 loads, 0 failures
# Read data for 298000 (743, 5)
# 233 loads, 0 failures
# Read data for 214320 (752, 5)
# 234 loads, 0 failures
# Read data for 048410 (752, 5)
# 235 loads, 0 failures
# Read data for 161890 (752, 5)
# 236 loads, 0 failures
# Read data for 020560 (752, 5)
# 237 loads, 0 failures
# Read data for 022100 (752, 5)
# 238 loads, 0 failures
# Read data for 005070 (752, 5)
# 239 loads, 0 failures
# Read data for 000670 (752, 5)
# 240 loads, 0 failures
# Read data for 140410 (752, 5)
# 241 loads, 0 failures
# Read data for 300720 (727, 5)
# 242 loads, 0 failures
# Read data for 003240 (752, 5)
# 243 loads, 0 failures
# Read data for 023590 (752, 5)
# 244 loads, 0 failures
# Read data for 000250 (752, 5)
# 245 loads, 0 failures
# Read data for 036540 (752, 5)
# 246 loads, 0 failures
# Read data for 001120 (752, 5)
# 247 loads, 0 failures
# Read data for 299660 (597, 5)
# 248 loads, 0 failures
# Read data for 084850 (420, 5)
# 249 loads, 0 failures
# Read data for 086520 (752, 5)
# 250 loads, 0 failures
# Read data for 192080 (752, 5)
# 251 loads, 0 failures
# Read data for 086450 (752, 5)
# 252 loads, 0 failures
# Read data for 014820 (752, 5)
# 253 loads, 0 failures
# Read data for 102460 (752, 5)
# 254 loads, 0 failures
# Read data for 003690 (752, 5)
# 255 loads, 0 failures
# Read data for 093370 (752, 5)
# 256 loads, 0 failures
# Read data for 009420 (752, 5)
# 257 loads, 0 failures
# Read data for 005690 (752, 5)
# 258 loads, 0 failures
# Read data for 383310 (36, 5)
# 259 loads, 0 failures
# Read data for 018670 (752, 5)
# 260 loads, 0 failures
# Read data for 144510 (752, 5)
# 261 loads, 0 failures
# Read data for 046890 (752, 5)
# 262 loads, 0 failures
# Read data for 039130 (752, 5)
# 263 loads, 0 failures
# Read data for 069080 (752, 5)
# 264 loads, 0 failures
# Read data for 001800 (752, 5)
# 265 loads, 0 failures
# Read data for 002840 (752, 5)
# 266 loads, 0 failures
# Read data for 001430 (752, 5)
# 267 loads, 0 failures
# Read data for 005880 (752, 5)
# 268 loads, 0 failures
# Read data for 003520 (752, 5)
# 269 loads, 0 failures
# Read data for 241590 (752, 5)
# 270 loads, 0 failures
# Read data for 365550 (140, 5)
# 271 loads, 0 failures
# Read data for 103140 (752, 5)
# 272 loads, 0 failures
# Read data for 079160 (752, 5)
# 273 loads, 0 failures
# Read data for 344820 (370, 5)
# 274 loads, 0 failures
# Read data for 057050 (752, 5)
# 275 loads, 0 failures
# Read data for 950220 (87, 5)
# 276 loads, 0 failures
# Read data for 267270 (752, 5)
# 277 loads, 0 failures
# Read data for 950130 (752, 5)
# 278 loads, 0 failures
# Read data for 039200 (752, 5)
# 279 loads, 0 failures
# Read data for 112040 (752, 5)
# 280 loads, 0 failures
# Read data for 025540 (752, 5)
# 281 loads, 0 failures
# Read data for 122870 (752, 5)
# 282 loads, 0 failures
# Read data for 284740 (752, 5)
# 283 loads, 0 failures
# Read data for 114090 (752, 5)
# 284 loads, 0 failures
# Read data for 003530 (752, 5)
# 285 loads, 0 failures
# Read data for 289220 (81, 5)
# 286 loads, 0 failures
# Read data for 194480 (752, 5)
# 287 loads, 0 failures
# Read data for 084370 (752, 5)
# 288 loads, 0 failures
# Read data for 005440 (752, 5)
# 289 loads, 0 failures
# Read data for 298380 (636, 5)
# 290 loads, 0 failures
# Read data for 003850 (752, 5)
# 291 loads, 0 failures
# Read data for 069260 (752, 5)
# 292 loads, 0 failures
# Read data for 001680 (752, 5)
# 293 loads, 0 failures
# Read data for 020000 (752, 5)
# 294 loads, 0 failures
# Read data for 064960 (752, 5)
# 295 loads, 0 failures
# Read data for 084990 (752, 5)
# 296 loads, 0 failures
# Read data for 006120 (752, 5)
# 297 loads, 0 failures
# Read data for 079550 (752, 5)
# 298 loads, 0 failures
# Read data for 151910 (752, 5)
# 299 loads, 0 failures
# Read data for 003540 (752, 5)
# 300 loads, 0 failures

# %%
# Read 주가데이터 per stock code and returns each day's up or down

def get_upDownDays(code):
  df_down = []
  df_up = []

  price_data = pd.read_csv(code+'_주가데이터.csv')

  df_down = price_data[price_data['UpDown']==0]['날짜']   
  df_up = price_data[price_data['UpDown']==1]['날짜']

  return df_up, df_down

# %%
def naver_news_title(stock, dates):
  result_list = []
  error_cnt = 0

  stock_name = code_names.get(stock)
  stock_encode = urllib.parse.quote(stock_name, encoding='euc-kr')


  base_url = 'https://finance.naver.com/news/news_search.nhn?rcdate=1&q={}&sm=title.basic&pd=4&stDateStart={}&stDateEnd={}'
  headers = {'User-Agent':'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/84.0.4147.89 Safari/537.36'}

  for date in dates:
    url = base_url.format(stock_encode, date, date)
    res = requests.get(url, headers=headers)

    # print("page: ", page)
    if res.status_code == 200:
      soup = BeautifulSoup(res.text)
      title_list = soup.select('.articleSubject')
      for title in title_list:
        try:
          news_title = title.select_one('a').text.strip()
          # news_title = news_title.replace(stock_name, '')
          # print("add: ", news_title)
          result_list.append([news_title])
        except:
          error_cnt += 1
  
  return result_list

# %%
headline_count = pd.DataFrame(columns=['code', 'name', 'counts'])

for code in code_lists:
  date_up, date_down = get_upDownDays(code)

  result_list = naver_news_title(code, date_up)
  title_df_up = pd.DataFrame(result_list, columns=['뉴스제목'])
  title_df_up['주가변동'] = 1

  result_list = naver_news_title(code, date_down)
  title_df_down = pd.DataFrame(result_list, columns=['뉴스제목'])
  title_df_down['주가변동'] = 0

  title_df = pd.concat([title_df_up, title_df_down])
  title_df.to_csv(code+'_뉴스타이틀.tsv', index=False, encoding='utf-8', sep="\t")

  stock_name = code_names.get(code)
  new_row = {'code':code, 'name':stock_name, 'counts':title_df.shape[0]}
  headline_count = headline_count.append(new_row, ignore_index=True) 
headline_count.to_csv('news_headline_counts.csv')
# headline_count

# %%
# headline_count = pd.DataFrame(columns=['code', 'name', 'counts'])
# count = 1
# for code in code_lists:
#     stock_name = code_names.get(code)
#     new_row = {'code':code, 'name':stock_name, 'counts':count}
#     headline_count = headline_count.append(new_row, ignore_index=True) 
#     count += 1
# headline_count.to_csv('news_headline_counts.csv')
# headline_count

# %%
all_headlines = pd.DataFrame()

for code in code_lists:
  title_df = pd.read_csv(code+'_뉴스타이틀.tsv', sep="\t")
  all_headlines = pd.concat([all_headlines, title_df])

# shuffle the DataFrame rows
all_headlines = all_headlines.sample(frac = 1)
all_headlines.to_csv('all_headlines.tsv', index=False, encoding='utf-8', sep="\t")

# %%
all_headlines
# Out:
#                                          뉴스제목 주가변동
# 478         LG생활건강, ‘숨37° 로시크숨마 황제의 빛 에디션’ 선봬    1
# 836         [IR]SK이노베이션 "내년 시설투자, 올해보다 낮은 수준"    1
# 1984               수출입銀, CJ대한통운 해외채권 발행 공동 보증    0
# 1192   브랜드 아파트 700만원대에 마련할 마지막 기회! ‘사천 KCC스위첸    1
# 12167                LG전자, 뉴욕 한복판에서 영화 상영한 사연    0
# ...                                       ...  ...
# 123      한국항공우주, 인니에 269억원 규모 KT-1B 훈련기 공급 계약    1
# 2136                     '하이트진로 3세' 박태영 사장 승진    1
# 1075         [특징주] '형제의 난' 재점화 가능성에...롯데지주 강세    0
# 610            제일기획, 비상교육과 청소년 대상 '마음 교과서' 개발    1
# 11629        KT주도 '클라우드 원팀'에 한컴 등 3개 기업·기관 합류    0
#
# [611473 rows x 2 columns]
